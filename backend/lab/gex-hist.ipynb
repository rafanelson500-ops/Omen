# %%
import databento
from dotenv import load_dotenv
import os
import requests
import gzip
import io
import pandas as pd
load_dotenv()
# Out:
# True

# %%
result = requests.get(
    "https://api.gex.bot/v2/hist/ES_SPX/orderflow/orderflow/2026-4-21?noredirect",
    headers={
        "Authorization": f"Bearer {os.getenv('GEXBOT_API_KEY')}",
        "Content-Type": "application/json",
        "User-Agent": "trading-botV1.0.0",
        "Accept": "application/json",
    }
)

download_url = result.json()['url']
print(download_url)
# response = requests.get(download_url)
# response.raise_for_status()

# raw = response.content
# if raw[:2] == b"\x1f\x8b":
#     raw = gzip.decompress(raw)

# df = pd.read_json(io.BytesIO(raw))
# df['timestamp'] = pd.to_datetime(df['timestamp'], unit='s', utc=True).dt.tz_convert('America/New_York')
# df
# Out:
# https://nfagexbotresearch.blob.core.windows.net:443/gexbot-history/ESSPX/2026-04-21_ES_SPX_orderflow_orderflow.json.gz?sv=2026-02-06&se=2026-04-22T04%3A51%3A03Z&sr=b&sp=r&sig=LcnIsRzT6yNage8r%2FK1c6Sbkk29%2F9I32ciuHCi%2B0Ej0%3D

# %%
df.to_csv('gex_full_2026-04-21.csv', index=False)
